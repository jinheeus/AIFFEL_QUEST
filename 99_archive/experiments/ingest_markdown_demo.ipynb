# %% [markdown]
# # Markdown-Native RAG Demo
#
# This notebook demonstrates how to process the LlamaParser-generated Markdown files to preserve their structure (headers, sections) during ingestion.
#
# ## Key Ideas
# 1. **Hierarchical Splitting**: Use `MarkdownHeaderTextSplitter` to keep text attached to its headers (e.g., `# Audit Result > ## Financial Loss`).
# 2. **Context Preservation**: The metadata from headers acts as "breadcrumbs" for the LLM.

# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-text-splitters) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.11.0)
# Requirement already satisfied: certifi in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/bychoi/miniforge3/envs/langchain-rag/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.3.1)

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

# Load the parsed single file for testing
input_file = "2538-00_parsed.md"
with open(input_file, "r", encoding="utf-8") as f:
    markdown_text = f.read()

print(f"Loaded {len(markdown_text)} characters.")
# print(markdown_text[:500])
# Out:
# Loaded 59 characters.

# %% [markdown]
# ### Step 1: Split by Headers
# We define the headers we want to track. LlamaParse usually creates standard `#`, `##` headers.

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
md_header_splits = markdown_splitter.split_text(markdown_text)

# CLEANING STEP: Remove superscript-like citations (e.g., '플라이애시1)', 'Ａ16)')
import re
def clean_text(text):
    # Remove patterns like '1)', '16)' that might be attached to words or isolated
    # Pattern: Digit(s) followed by ')'
    text = re.sub(r'(?<=\w)\d+\)', '', text)  # remove '플라이애시1)' -> '플라이애시'
    text = re.sub(r'\s[Ａ-Ｚ]+\d+\)', '', text) # remove ' Ａ16)'
    text = re.sub(r'\. {3,}', '', text)  # Remove TOC dots (e.g., '......')
    return text

for doc in md_header_splits:
    doc.page_content = clean_text(doc.page_content)

print(f"Split into {len(md_header_splits)} Parent Sections based on headers (and cleaned).")

# --- PARENT-CHILD SIMULATION ---
# Let's say we define a 'Child Chunk' size. If a section is smaller, Child == Parent.
from langchain_text_splitters import RecursiveCharacterTextSplitter

child_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)

print("\n--- Simulating Parent-Child Indexing ---")
documents_to_index = []

for parent_doc in md_header_splits[:5]: # look at first 5 sections
    parent_text = parent_doc.page_content
    breadcrumbs = parent_doc.metadata
    
    # Split parent into children
    child_chunks = child_splitter.create_documents([parent_text])
    
    print(f"Parent Section: {breadcrumbs} (Length: {len(parent_text)}) -> {len(child_chunks)} Children")
    
    for i, child in enumerate(child_chunks):
        # This is what goes into Milvus
        record = {
            "vector": "(Embedding of Child Text)",
            "text": child.page_content,           # Child Text (Search Target)
            "parent_text": parent_text,           # Parent Text (LLM Context)
            "breadcrumbs": str(breadcrumbs),      # Context Path
            "idx": f"Section_{i}"               # ID
        }
        documents_to_index.append(record)
        # if i == 0:
        #    print(f"  [Child 1 Preview]: {child.page_content[:50]}...")
# Out:
# Split into 1 Parent Sections based on headers (and cleaned).
#
# --- Simulating Parent-Child Indexing ---
# Parent Section: {'Header 1': '- 변상판정 청구사항 서면감사 -'} (Length: 16) -> 1 Children

# %% [markdown]
# ### Step 2: Inspection
# See how the metadata captures the document structure.

# %%
for i, doc in enumerate(md_header_splits[:5]):
    print(f"--- Parent Chunk {i} ---")
    print(f"Metadata: {doc.metadata}")
    # print(doc.page_content[:100]) # Commented out to reduce noise
# Out:
# --- Parent Chunk 0 ---
# Metadata: {'Header 1': '- 변상판정 청구사항 서면감사 -'}
